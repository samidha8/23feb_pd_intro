# %%
#Q1. Create a Pandas Series that contains the following data: 4, 8, 15, 16, 23, and 42. Then, print the series.

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
s1= pd.Series([4, 8, 15, 16, 23,42])
print(s1)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
#Q2. Create a variable of list type containing 10 elements in it, and apply pandas.Series function on the variable print it.

# %%
dict2 ={"Name":['lice','Bob','Claire'],
        "Age": [25 ,30 ,27],
        "Gender":['Male','Male',"Female"],
        "Education":["bpharm","mpharm","mba"],
        "job":["analyst","manager","hr"],
        "cgpa":[8.35,5.67,7.00],
        "payments":[500,1000,1500]}

# %%
veriable= pd.Series(dict2)

# %%
veriable
# Out:
# Name            [lice, Bob, Claire]
# Age                    [25, 30, 27]
# Gender         [Male, Male, Female]
# Education     [bpharm, mpharm, mba]
# job          [analyst, manager, hr]
# cgpa              [8.35, 5.67, 7.0]
# payments          [500, 1000, 1500]
# dtype: object

# %%
veriable['Age']
# Out:
# [25, 30, 27]

# %%
#Q3. Create a Pandas DataFrame that contains the following data:

# %%
dict1 = {"Name":[ 'Alice','Bob','Claire'],
        "Age": [25 ,30 ,27],
        "Gender":['Female','Male','Female']}

# %%
type(dict1)
# Out:
# dict

# %%
l1= pd.Series(dict1)
print(l1)
# Out:
# Name        [Alice, Bob, Claire]
# Age                 [25, 30, 27]
# Gender    [Female, Male, Female]
# dtype: object

# %%
type(l1)
# Out:
# pandas.core.series.Series

# %%
pd.DataFrame(dict1)
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %%
#Q4. What is ‘DataFrame’ in pandas and how is it different from pandas.series?

# %%
"""pandas DataFrame is a Two-Dimensional data structure, an immutable, heterogeneous tabular data structure with labeled axes rows, and columns. pandas Dataframe consists of three components principal, data, rows, and columns."""
# Out:
# 'pandas DataFrame is a Two-Dimensional data structure, an immutable, heterogeneous tabular data structure with labeled axes rows, and columns. pandas Dataframe consists of three components principal, data, rows, and columns.'

# %%
difference = {"Property":["Series","DataFrame"],
    "Dimensions":['1-Dimentional', "2-Dimentional"],
             "Type of Data":["Homogeneous- All elements must be of same data type","Heterogeneous- DataFrame objects can have different data types"],
             "Mutability Size":["Immutable- Size of a series object, once created, cannot change Size","Mutable-  We can drop or add the elements in anexisting dataframe objec"]}

# %%
#in pandas how is DataFrame different from pandas.series?
pd.DataFrame(difference)
# Out:
#     Property     Dimensions  \
# 0     Series  1-Dimentional
# 1  DataFrame  2-Dimentional
#
#                                         Type of Data  \
# 0  Homogeneous- All elements must be of same data...
# 1  Heterogeneous- DataFrame objects can have diff...
#
#                                      Mutability Size
# 0  Immutable- Size of a series object, once creat...
# 1  Mutable-  We can drop or add the elements in a...

# %%
#Explain with an example
dict2 = {"Name":[ 'samidha','samruddhi','sayali'],
        "Age": [25 ,30 ,27],
        "Gender":['Female','Female','Female'],
        "Address":["vangaon","vangaon","badlapur"]}

# %%
pd.DataFrame(dict2)
#this show data in 2D
#DataFrames support named rows & columns
#Supporting reading flat files like CSV, Excel, and JSON
#Can perform arithmetic operations on rows and columns.
# Out:
#         Name  Age  Gender   Address
# 0    samidha   25  Female   vangaon
# 1  samruddhi   30  Female   vangaon
# 2     sayali   27  Female  badlapur

# %%
type(pd.DataFrame(dict2))
# Out:
# pandas.core.frame.DataFrame

# %%
pd.Series(dict2)
##this show data in 1D
# Out:
# Name       [samidha, samruddhi, sayali]
# Age                        [25, 30, 27]
# Gender         [Female, Female, Female]
# Address    [vangaon, vangaon, badlapur]
# dtype: object

# %%
type(pd.Series(dict2))
# Out:
# pandas.core.series.Series

# %%
"""Q5. What are some common functions you can use to manipulate data in a Pandas DataFrame? Can you give an example of when you might use one of these functions?"""
# Out:
# 'Q5. What are some common functions you can use to manipulate data in a Pandas DataFrame? Can you give an example of when you might use one of these functions?'

# %%
#Read csv,excel files
#Dropping columns in the data.
#Dropping rows in the data.
#Renaming a column in the dataset.
#Select columns with specific data types.
#Slicing the dataset.

# %%
#Read csv,excel files
eg1= pd.read_csv("services.csv")

# %%
eg1
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
#to save this csv data
eg1.to_csv("services.csv")

# %%
#to delete/remove index from dataframe
eg1.to_csv("services_indexFalse.csv",index = False)

# %%
# drop() method removes the specified row or column.
#By specifying the column axis ( axis='columns' ), the drop() method removes the specified column. 
#By specifying the row axis ( axis='index' ), the drop() method removes the specified row.
# Remove column name 'A'

# %%
#show starting 2 rows
eg1.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
#show ending 2 rows
eg1.tail(2)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...        None
#
#                     email  ...  \
# 21  passports@example.org  ...
# 22                    NaN  ...
#
#                               interpretation_services  \
# 21  We offer 3-way interpretation services over th...
# ...

# %%
#statistic analysis
eg1.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
#show all columns
eg1.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
#gives whatever present in application_process in  Series format
eg1["application_process"]
# Out:
# 0                            Walk in or apply by phone.
# 1                    Apply by phone for an appointment.
# 2           Phone for information (403-4300 Ext. 4322).
# 3                                       Apply by phone.
# 4                                Phone for information.
# 5     Walk in or apply by phone for membership appli...
# 6     Apply by phone or be referred by a doctor, soc...
# 7                                       Apply by phone.
# 8     Walk in. Proof of residency in California requ...
# 9     Walk in. Proof of California residency to rece...
# 10    Walk in. Proof of California residency require...
# 11    Walk in or apply by phone, email or webpage re...
# 12    Walk in. Proof of California residency require...
# 13    Call for appointment. Referral from human serv...
# 14            Walk in or through other agency referral.
# 15    Walk in. Written application, identification r...
# 16                                Call for information.
# ...

# %%
#want to change values in application_process
eg1['application_process'][0]= " Walk in or apply by phone or mail"
# Out:
# /tmp/ipykernel_154/1643039178.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eg1['application_process'][0]= " Walk in or apply by phone or mail"

# %%
eg1['application_process']
# Out:
# 0                     Walk in or apply by phone or mail
# 1                    Apply by phone for an appointment.
# 2           Phone for information (403-4300 Ext. 4322).
# 3                                       Apply by phone.
# 4                                Phone for information.
# 5     Walk in or apply by phone for membership appli...
# 6     Apply by phone or be referred by a doctor, soc...
# 7                                       Apply by phone.
# 8     Walk in. Proof of residency in California requ...
# 9     Walk in. Proof of California residency to rece...
# 10    Walk in. Proof of California residency require...
# 11    Walk in or apply by phone, email or webpage re...
# 12    Walk in. Proof of California residency require...
# 13    Call for appointment. Referral from human serv...
# 14            Walk in or through other agency referral.
# 15    Walk in. Written application, identification r...
# 16                                Call for information.
# ...

# %%
#Q6. Which of the following is mutable in nature Series, DataFrame, Panel?

# %%
mutability= {"series":["immuteble"]," DataFrame":["mutable"],"Panel":["mutable"]}
#All Pandas data structures are value mutable (can be changed) and except Series all are size mutable.

# %%
pd.DataFrame(mutability)
# Out:
#       series  DataFrame    Panel
# 0  immuteble    mutable  mutable

# %%
#Q7. Create a DataFrame using multiple Series. Explain with an example.

# %%
"""By using concat() method you can merge multiple series together into DataFrame. This takes several params, for our scenario we use list that takes series to combine and axis=1 to specify merge series as columns instead of rows. Note that using axis=0 appends series to rows instead of columns."""
# Out:
# 'By using concat() method you can merge multiple series together into DataFrame. This takes several params, for our scenario we use list that takes series to combine and axis=1 to specify merge series as columns instead of rows. Note that using axis=0 appends series to rows instead of columns.'

# %%
## Create pandas Series
courses = pd.Series(["Spark","PySpark","Hadoop"])
fees = pd.Series([22000,25000,2300])
discount  = pd.Series([1000,2300,1000])

# %%
#combine all the series
df=pd.concat([courses,fees,discount],axis=1)

# %%
df
# Out:
#          0      1     2
# 0    Spark  22000  1000
# 1  PySpark  25000  2300
# 2   Hadoop   2300  1000

# %%
#combine 2 series
df1=pd.concat([courses,fees],axis=1)

# %%
df1
# Out:
#          0      1
# 0    Spark  22000
# 1  PySpark  25000
# 2   Hadoop   2300

# %%
df3=pd.concat([courses,fees,discount],axis=0)

# %%
df3
# Out:
# 0      Spark
# 1    PySpark
# 2     Hadoop
# 0      22000
# 1      25000
# 2       2300
# 0       1000
# 1       2300
# 2       1000
# dtype: object
